# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
df = pd.read_csv("/content/cods.csv")

# %%
df.head()
# Out:
#              class        x1        y1        z1        v1        x2  \
# 0  Wakanda Forever  0.462706  0.431580 -0.757153  0.998437  0.487584
# 1  Wakanda Forever  0.518201  0.431670 -0.887636  0.998549  0.548550
# 2  Wakanda Forever  0.547669  0.435994 -0.964934  0.998667  0.574164
# 3  Wakanda Forever  0.556394  0.437452 -0.858350  0.998775  0.582997
# 4  Wakanda Forever  0.565045  0.437322 -0.685120  0.998891  0.590076
#
#          y2        z2        v2        x3  ...      z499  v499      x500  \
# 0  0.377986 -0.755726  0.998260  0.504571  ... -0.011850   0.0  0.524245
# 1  0.377994 -0.856575  0.998382  0.565107  ... -0.007271   0.0  0.575864
# 2  0.381405 -0.927102  0.998517  0.589339  ... -0.007569   0.0  0.592384
# 3  0.381988 -0.831006  0.998636  0.597340  ... -0.007243   0.0  0.603788
# 4  0.381727 -0.646904  0.998764  0.602363  ... -0.007150   0.0  0.612066
#
#        y500      z500  v500      x501      y501      z501  v501
# 0  0.373264 -0.029718   0.0  0.529352  0.368006 -0.031992   0.0
# 1  0.379582 -0.003797   0.0  0.580175  0.375582 -0.004541   0.0
# 2  0.387663  0.002439   0.0  0.596274  0.384979  0.002115   0.0
# 3  0.385984  0.007347   0.0  0.607334  0.383157  0.007451   0.0
# 4  0.378345  0.010053   0.0  0.615339  0.375624  0.010318   0.0
#
# [5 rows x 2005 columns]

# %%
df['class'].value_counts()
# Out:
# class
# Wakanda Forever    126
# waving              78
# Kill                72
# Happy               71
# Sad                 71
# Clapping            69
# Namaste             62
# Victory             51
# Crying              25
# Name: count, dtype: int64

# %%
df[df['class']=='Sad']
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 197   Sad  0.573944  0.512185 -1.014540  0.999901  0.607800  0.445765
# 198   Sad  0.573935  0.475625 -1.058830  0.999899  0.606785  0.408270
# 199   Sad  0.567638  0.459368 -1.061838  0.999904  0.597630  0.391168
# 200   Sad  0.560957  0.455830 -0.955743  0.999903  0.589443  0.388916
# 201   Sad  0.554989  0.458537 -0.793884  0.999906  0.583915  0.391170
# ..    ...       ...       ...       ...       ...       ...       ...
# 263   Sad  0.565373  0.565652 -1.513740  0.999704  0.597280  0.488637
# 264   Sad  0.565283  0.540374 -1.409634  0.999724  0.596843  0.464813
# 265   Sad  0.564785  0.529279 -1.364350  0.999743  0.596329  0.454179
# 266   Sad  0.563495  0.521767 -1.395360  0.999759  0.593241  0.446669
# 267   Sad  0.558978  0.518343 -1.405367  0.999773  0.586874  0.443744
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 197 -0.954328  0.999732  0.623259  ... -0.018857   0.0  0.639410  0.437783
# 198 -0.994271  0.999739  0.622151  ... -0.011213   0.0  0.636131  0.390579
# 199 -1.000241  0.999754  0.614256  ... -0.005451   0.0  0.622680  0.383542
# 200 -0.900216  0.999761  0.607400  ... -0.009276   0.0  0.617865  0.387818
# 201 -0.753339  0.999771  0.602143  ... -0.011207   0.0  0.616886  0.394575
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 263 -1.477126  0.999413  0.614493  ... -0.028429   0.0  0.625571  0.469718
# 264 -1.367938  0.999455  0.614073  ... -0.023747   0.0  0.625197  0.452557
# 265 -1.317212  0.999495  0.613592  ... -0.022185   0.0  0.624844  0.444947
# 266 -1.348116  0.999527  0.609301  ... -0.022432   0.0  0.618377  0.438303
# 267 -1.360044  0.999554  0.602961  ... -0.021187   0.0  0.616547  0.437931
#
#          z500  v500      x501      y501      z501  v501
# 197 -0.007111   0.0  0.644713  0.432081 -0.007603   0.0
# 198  0.006499   0.0  0.641069  0.385234  0.006669   0.0
# 199  0.014865   0.0  0.627332  0.378858  0.015305   0.0
# 200  0.010453   0.0  0.622486  0.383762  0.010743   0.0
# 201  0.008831   0.0  0.621175  0.390824  0.009023   0.0
# ..        ...   ...       ...       ...       ...   ...
# 263 -0.011760   0.0  0.630174  0.463347 -0.012125   0.0
# 264 -0.004132   0.0  0.629748  0.446231 -0.004205   0.0
# 265  0.000120   0.0  0.629110  0.438636  0.000429   0.0
# 266  0.001711   0.0  0.622474  0.431755  0.002152   0.0
# 267  0.002537   0.0  0.620586  0.431734  0.002962   0.0
#
# [71 rows x 2005 columns]

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Happy', 'Victory', 'Namaste', 'Happy', 'Kill', 'Kill', 'Sad',
#        'Namaste', 'Kill', 'Happy', 'Kill', 'Clapping', 'Happy', 'waving',
#        'Namaste', 'Namaste', 'Kill', 'Clapping', 'Happy', 'Sad',
#        'Wakanda Forever', 'Victory', 'Happy', 'waving', 'Happy',
#        'Victory', 'waving', 'Wakanda Forever', 'Clapping', 'waving',
#        'Victory', 'Clapping', 'Clapping', 'Happy', 'Sad', 'Clapping',
#        'Sad', 'waving', 'Clapping', 'waving', 'waving', 'Sad',
#        'Wakanda Forever', 'Namaste', 'waving', 'Clapping',
#        'Wakanda Forever', 'Namaste', 'Wakanda Forever', 'Victory',
#        'Happy', 'Happy', 'Sad', 'Sad', 'Kill', 'Wakanda Forever',
#        'Wakanda Forever', 'Clapping', 'Happy', 'Wakanda Forever',
#        'Wakanda Forever', 'Kill', 'Happy', 'Victory', 'Victory',
#        'Namaste', 'Kill', 'Namaste', 'Namaste', 'Sad', 'waving',
#        'Clapping', 'Sad', 'Namaste', 'Clapping', 'Crying',
#        'Wakanda Forever', 'Kill', 'Clapping', 'Wakanda Forever', 'Happy',
#        'Clapping', 'waving', 'Kill', 'Wakanda Forever', 'Victory',
#        'waving', 'waving', 'waving', 'Happy', 'Wakanda Forever', 'waving',
#        'Kill', 'Happy', 'Wakanda Forever', 'Happy', 'Sad',
#        'Wakanda Forever', 'waving', 'Kill', 'Namaste', 'Clapping',
#        'Crying', 'waving', 'Namaste', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Happy', 'waving', 'Sad', 'Victory',
#        'Crying', 'Sad', 'Kill', 'Kill', 'Clapping', 'waving', 'Victory',
#        'Happy', 'Happy', 'Sad', 'Crying', 'Kill', 'Namaste', 'Namaste',
#        'Crying', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Sad', 'Sad', 'waving',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever', 'Crying',
#        'Happy', 'Kill', 'Wakanda Forever', 'Happy', 'Clapping', 'waving',
#        'Kill', 'Wakanda Forever', 'Wakanda Forever', 'Namaste', 'Crying',
#        'Wakanda Forever', 'Sad', 'waving', 'Kill', 'Sad', 'Sad', 'Sad',
#        'Kill', 'Namaste', 'Wakanda Forever', 'Clapping', 'waving', 'Sad',
#        'Wakanda Forever', 'waving', 'Victory', 'Crying', 'Victory',
#        'Wakanda Forever', 'waving', 'Wakanda Forever', 'Clapping',
#        'waving', 'Kill', 'waving', 'Clapping', 'Namaste', 'Namaste',
#        'Crying', 'Wakanda Forever', 'Clapping', 'Crying', 'Clapping',
#        'Clapping', 'waving', 'Happy', 'waving', 'Kill'], dtype='<U15')

# %%
from sklearn.metrics import accuracy_score
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9946808510638298
# rc 1.0
# rf 1.0
# gb 0.9787234042553191

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Happy', 'Victory', 'Namaste', 'Happy', 'Kill', 'Kill', 'Sad',
#        'Namaste', 'Kill', 'Happy', 'Kill', 'Clapping', 'Happy', 'waving',
#        'Namaste', 'Namaste', 'Kill', 'Clapping', 'Happy', 'Sad',
#        'Wakanda Forever', 'Victory', 'Happy', 'waving', 'Happy',
#        'Victory', 'waving', 'Wakanda Forever', 'Clapping', 'waving',
#        'Victory', 'Clapping', 'Clapping', 'Happy', 'Sad', 'Clapping',
#        'Sad', 'waving', 'Clapping', 'waving', 'waving', 'Sad',
#        'Wakanda Forever', 'Namaste', 'waving', 'Clapping',
#        'Wakanda Forever', 'Namaste', 'Wakanda Forever', 'Victory',
#        'Happy', 'Happy', 'Sad', 'Sad', 'Kill', 'Wakanda Forever',
#        'Wakanda Forever', 'Clapping', 'Happy', 'Wakanda Forever',
#        'Wakanda Forever', 'Kill', 'Happy', 'Victory', 'Victory',
#        'Namaste', 'Kill', 'Namaste', 'Namaste', 'Sad', 'waving',
#        'Clapping', 'Sad', 'Namaste', 'Clapping', 'Crying',
#        'Wakanda Forever', 'Kill', 'Clapping', 'Wakanda Forever', 'Happy',
#        'Clapping', 'waving', 'Kill', 'Wakanda Forever', 'Victory',
#        'waving', 'waving', 'waving', 'Happy', 'Wakanda Forever', 'waving',
#        'Kill', 'Happy', 'Wakanda Forever', 'Happy', 'Sad',
#        'Wakanda Forever', 'waving', 'Kill', 'Namaste', 'Clapping',
#        'Crying', 'waving', 'Namaste', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Happy', 'waving', 'Sad', 'Victory',
#        'Crying', 'Sad', 'Kill', 'Kill', 'Clapping', 'waving', 'Victory',
#        'Happy', 'Happy', 'Sad', 'Crying', 'Kill', 'Namaste', 'Namaste',
#        'Crying', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Sad', 'Sad', 'waving',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever', 'Crying',
#        'Happy', 'Kill', 'Wakanda Forever', 'Happy', 'Clapping', 'waving',
#        'Kill', 'Wakanda Forever', 'Wakanda Forever', 'Namaste', 'Crying',
#        'Wakanda Forever', 'Sad', 'waving', 'Kill', 'Sad', 'Sad', 'Sad',
#        'Kill', 'Namaste', 'Wakanda Forever', 'Clapping', 'waving', 'Sad',
#        'Wakanda Forever', 'waving', 'Victory', 'Crying', 'Victory',
#        'Wakanda Forever', 'waving', 'Wakanda Forever', 'Clapping',
#        'waving', 'Kill', 'waving', 'Clapping', 'Namaste', 'Namaste',
#        'Crying', 'Wakanda Forever', 'Clapping', 'Crying', 'Clapping',
#        'Clapping', 'waving', 'Happy', 'waving', 'Kill'], dtype=object)

# %%
y_test
# Out:
# 181       Happy
# 301     Victory
# 398     Namaste
# 160       Happy
# 580        Kill
#          ...
# 521    Clapping
# 381      waving
# 194       Happy
# 348      waving
# 567        Kill
# Name: class, Length: 188, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)
